# %% [markdown]
# # Hill Climbing with simulated annealing - Traveling Salesman Problem (TSP)

# %%
import sys
sys.path.insert(0, '../src')

import tsp
import tsp_simulated_annealing as tsp_sa

# %%
import itertools
from PIL import Image

# %% [markdown]
# ### Swapping cities

# %% [markdown]
# #### Size 50

# %%
size = 50
coords = tsp.random_coordinates(size)
distances = tsp.euclid_distances(coords)
evaluation = lambda t: tsp.tour_length(distances, t)
init_func = lambda: tsp.random_tour(len(coords))

# %%
result = tsp_sa.tsp_hillclimb_simulated_annealing_restart(init_func, evaluation, tsp.swapped_cities_generator,\
         max_iterations=10000000, annealing_prob=tsp_sa.prob, annealing_temp=1.0, annealing_temp_decrease=0.95,\
         restart_limit=10, verbose=1)
# Out:
# restart 0
# result eval: 9.404668879735052 num_of_nexts: 177 num_of_iterations: 13611
# new best
# restart 1
# result eval: 8.414117242425235 num_of_nexts: 199 num_of_iterations: 23774
# new best
# restart 2
# result eval: 9.536017396284194 num_of_nexts: 166 num_of_iterations: 32426
# restart 3
# result eval: 8.57586919871883 num_of_nexts: 196 num_of_iterations: 43457
# restart 4
# result eval: 8.006086699464722 num_of_nexts: 176 num_of_iterations: 53994
# new best
# restart 5
# result eval: 8.77824066515002 num_of_nexts: 181 num_of_iterations: 67137
# restart 6
# result eval: 9.90542505501331 num_of_nexts: 138 num_of_iterations: 73135
# restart 7
# result eval: 9.612714465879217 num_of_nexts: 147 num_of_iterations: 80992
# restart 8
# result eval: 9.31314008773595 num_of_nexts: 158 num_of_iterations: 90727
# restart 9
# result eval: 9.069525031050775 num_of_nexts: 185 num_of_iterations: 99783

# %%
print("Best evaluation:", result['best_eval'])
print("Is local optimum:", result['local_optimum'])
print("Num of evaluations:", result['num_of_evaluations'])
print("Num of restarts:", result['num_of_restarts'])
# Out:
# Best evaluation: 8.006086699464722
# Is local optimum: True
# Num of evaluations: 99783
# Num of restarts: 10

# %%
tsp.draw_tour(coords,result["best_tour"],img_file="tour_best.png")

# %%
image = Image.open('tour_best.png')
display(image)#image.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1052x1051 at 0x2A09763B6A0>

# %% [markdown]
# ### Reversing sections

# %% [markdown]
# #### Size 50

# %%
size = 50
coords = tsp.random_coordinates(size)
distances = tsp.euclid_distances(coords)
evaluation = lambda t: tsp.tour_length(distances, t)
init_func = lambda: tsp.random_tour(len(coords))

# %%
result = tsp_sa.tsp_hillclimb_simulated_annealing_restart(init_func, evaluation, tsp.reversed_sections_generator,\
         max_iterations=10000000, annealing_prob=tsp_sa.prob, annealing_temp=1.0, annealing_temp_decrease=0.95,\
         restart_limit=10, verbose=1)
# Out:
# restart 0
# result eval: 5.752829675225475 num_of_nexts: 2873 num_of_iterations: 2806663
# new best
# restart 1
# result eval: 5.72400224209493 num_of_nexts: 2873 num_of_iterations: 5323555
# new best
# restart 2
# result eval: 5.5352387369080756 num_of_nexts: 2873 num_of_iterations: 8255961
# new best
# restart 3
# result eval: 5.637344223471693 num_of_nexts: 681 num_of_iterations: 8507423
# restart 4
# result eval: 6.098762191846966 num_of_nexts: 685 num_of_iterations: 8759541
# restart 5
# result eval: 5.912884415951537 num_of_nexts: 1462 num_of_iterations: 10000001

# %%
print("Best evaluation:", result['best_eval'])
print("Is local optimum:", result['local_optimum'])
print("Num of evaluations:", result['num_of_evaluations'])
print("Num of restarts:", result['num_of_restarts'])
# Out:
# Best evaluation: 5.5352387369080756
# Is local optimum: True
# Num of evaluations: 10000001
# Num of restarts: 6

# %%
tsp.draw_tour(coords,result["best_tour"],img_file="tour_best.png")

# %%
image = Image.open('tour_best.png')
display(image)#image.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1032x1032 at 0x2A097659BE0>
