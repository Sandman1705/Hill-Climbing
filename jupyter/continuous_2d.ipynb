# %% [markdown]
# # Hill Climbing - Continuous version, 2d

# %%
import sys
sys.path.insert(0, '../src')

import continuous_2d as hc
import numpy as np

# %% [markdown]
# #### Function with only one local maximum

# %%
result, iters = hc.continious_hill_climbing_simple_2d_random_move(hc.f,init_pos=-7.125, max_iter=1000, verbose=0)
print("Steps taken:", len(result)-1)
print("Num of iterations:", iters)
print("Local optimum:", hc.f(result[-1]))
print("Global optimum:", hc.f(3.1))
hc.draw_graph_2d_and_steps(hc.f,result,show=True)
# Out:
# Steps taken: 19
# Num of iterations: 71
# Local optimum: -1.4551915221590587e-13
# Global optimum: -0.0

# %% [markdown]
# #### Function with more than one local maximum - bad starting position

# %%
result, iters = hc.continious_hill_climbing_simple_2d_random_move(hc.f2,init_pos=-1.125, max_iter=1000, verbose=0)
print("Steps taken:", len(result)-1)
print("Num of iterations:", iters)
print("Local optimum:", hc.f(result[-1]))
print("Global optimum (~):", hc.f(9.79771))
hc.draw_graph_2d_and_steps(hc.f2,result,show=True)
# Out:
# Steps taken: 12
# Num of iterations: 58
# Local optimum: -102.01223466189636
# Global optimum (~): -44.85931924410001

# %% [markdown]
# #### Function with more than one local maximum - good starting position

# %%
result, iters = hc.continious_hill_climbing_simple_2d_random_move(hc.f2,init_pos=1.125, max_iter=1000, verbose=0)
print("Steps taken:", len(result)-1)
print("Num of iterations:", iters)
print("Local optimum:", hc.f(result[-1]))
print("Global optimum (~):", hc.f(9.79771))
hc.draw_graph_2d_and_steps(hc.f2,result,show=True)
# Out:
# Steps taken: 19
# Num of iterations: 66
# Local optimum: -44.85935040251949
# Global optimum (~): -44.85931924410001
