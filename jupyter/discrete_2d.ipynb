# %% [markdown]
# # Hill Climbing - Discrete version, 2d

# %%
import sys
sys.path.insert(0, '../src')

import discrete_2d as hc
import numpy as np

# %% [markdown]
# #### Example size of (20,20)

# %%
test_matrix = np.array(hc.f_2d_int_hill(sizes=(20,20),max_value=0))
result, iters = hc.discrete_hill_climbing_simple_2d_random_move(test_matrix,init_pos=(0,0),verbose=False,step=10)
print("Num of steps:", len(result)-1, "Iterations:", iters, "Local optimum:", test_matrix[result[-1]], "Global optimum:", 0)
hc.draw_2d_discrete_with_path(test_matrix,result,draw_steps=True,show=True)
# Out:
# Num of steps: 9 Iterations: 50 Local optimum: 0 Global optimum: 0

# %% [markdown]
# #### Examples of size (50,50)

# %%
test_matrix = np.array(hc.f_2d_int_hill(sizes=(50,50),max_value=0))
result, iters = hc.discrete_hill_climbing_simple_2d_random_move(test_matrix,init_pos=(0,0),verbose=False,step=20)
print("Num of steps:", len(result)-1, "Iterations:", iters, "Local optimum:", test_matrix[result[-1]], "Global optimum:", 0)
hc.draw_2d_discrete_with_path(test_matrix,result,draw_steps=True,show=True)
# Out:
# Num of steps: 16 Iterations: 85 Local optimum: 0 Global optimum: 0

# %% [markdown]
# #### Example of size (100,100)

# %%
test_matrix = np.array(hc.f_2d_int_hill(sizes=(100,100),max_value=0))
result, iters = hc.discrete_hill_climbing_simple_2d_random_move(test_matrix,init_pos=(0,0),verbose=False,step=50)
print("Num of steps:", len(result)-1, "Iterations:", iters, "Local optimum:", test_matrix[result[-1]], "Global optimum:", 0)
hc.draw_2d_discrete_with_path(test_matrix,result,draw_steps=True,show=True)
# Out:
# Num of steps: 50 Iterations: 252 Local optimum: 0 Global optimum: 0

# %% [markdown]
# #### Random function example (50,50)

# %%
test_matrix = np.array(hc.f_2d_randint(sizes=(50,50),max_value=100))
result, iters = hc.discrete_hill_climbing_simple_2d_random_move(test_matrix,init_pos=(0,0),verbose=False,step=20,shuffle=False)
print("Num of steps:", len(result)-1, "Iterations:", iters, "Local optimum:", test_matrix[result[-1]], "Global optimum:", np.max(test_matrix))
hc.draw_2d_discrete_with_path(test_matrix,result,draw_steps=True,show=True)
# Out:
# Num of steps: 2 Iterations: 83 Local optimum: 97 Global optimum: 99

# %% [markdown]
# #### Random function example (20,20)

# %%
test_matrix = np.array(hc.f_2d_randint(sizes=(20,20),max_value=100))
result, iters = hc.discrete_hill_climbing_simple_2d_random_move(test_matrix,init_pos=(0,0),verbose=False,step=10,shuffle=False)
print("Num of steps:", len(result)-1, "Iterations:", iters, "Local optimum:", test_matrix[result[-1]], "Global optimum:", np.max(test_matrix))
hc.draw_2d_discrete_with_path(test_matrix,result,draw_steps=True,show=True)
# Out:
# Num of steps: 2 Iterations: 26 Local optimum: 98 Global optimum: 99
